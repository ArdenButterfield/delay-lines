# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import scipy.fftpack as fp

# %%
im = np.random.random((200,200))

# %%
def makeFiltered(im, minimum, maximum):
    F1 = fp.fft2((im).astype(float))
    F2 = fp.fftshift(F1)

    (w, h) = im.shape
    half_w, half_h = int(w/2), int(h/2)
    
    # high pass filter
    F2[half_w - minimum : half_w + minimum + 1, half_h - minimum : half_h + minimum + 1] = 0 # select all but the first 50x50 (low) frequencies
    F2[:half_w - maximum, :] = 0
    F2[half_w + maximum:, :] = 0
    F2[:, :half_h - maximum] = 0
    F2[:, half_h + maximum:] = 0
    im1 = fp.ifft2(fp.ifftshift(F2)).real
    return im1

# %%
with open('FilteredSquares.cpp', 'w') as f:
    f.write('#include "FilteredSquares.h"\n#include <array>\n#include <unordered_map>\n\n')
    f.write('const std::unordered_map<int, std::array<unsigned char, 200 * 200>> filteredSquares = {\n')
    for minimum in range(0, 100, 5):
        for maximum in range(minimum + 5, 105, 5):
            print(minimum, maximum)
            f.write(f'\t{{{minimum * 1000 + maximum}, {{')
            filtered = makeFiltered(im, minimum, maximum)
            f.write(','.join((filtered.flatten() * 256).astype(np.uint8).astype(str)))
            f.write('}},\n')
    f.write('};\n')
# Out:
# 0 5
# 0 10
# 0 15
# 0 20
# 0 25
# 0 30
# 0 35
# 0 40
# 0 45
# 0 50
# 0 55
# 0 60
# 0 65
# 0 70
# 0 75
# 0 80
# 0 85
# 0 90
# 0 95
# 0 100
# 5 10
# 5 15
# 5 20
# 5 25
# 5 30
# 5 35
# 5 40
# 5 45
# 5 50
# 5 55
# 5 60
# 5 65
# 5 70
# 5 75
# 5 80
# 5 85
# 5 90
# 5 95
# 5 100
# 10 15
# 10 20
# 10 25
# 10 30
# 10 35
# 10 40
# 10 45
# 10 50
# 10 55
# 10 60
# 10 65
# 10 70
# 10 75
# 10 80
# 10 85
# 10 90
# 10 95
# 10 100
# 15 20
# 15 25
# 15 30
# 15 35
# 15 40
# 15 45
# 15 50
# 15 55
# 15 60
# 15 65
# 15 70
# 15 75
# 15 80
# 15 85
# 15 90
# 15 95
# 15 100
# 20 25
# 20 30
# 20 35
# 20 40
# 20 45
# 20 50
# 20 55
# 20 60
# 20 65
# 20 70
# 20 75
# 20 80
# 20 85
# 20 90
# 20 95
# 20 100
# 25 30
# 25 35
# 25 40
# 25 45
# 25 50
# 25 55
# 25 60
# 25 65
# 25 70
# 25 75
# 25 80
# 25 85
# 25 90
# 25 95
# 25 100
# 30 35
# 30 40
# 30 45
# 30 50
# 30 55
# 30 60
# 30 65
# 30 70
# 30 75
# 30 80
# 30 85
# 30 90
# 30 95
# 30 100
# 35 40
# 35 45
# 35 50
# 35 55
# 35 60
# 35 65
# 35 70
# 35 75
# 35 80
# 35 85
# 35 90
# 35 95
# 35 100
# 40 45
# 40 50
# 40 55
# 40 60
# 40 65
# 40 70
# 40 75
# 40 80
# 40 85
# 40 90
# 40 95
# 40 100
# 45 50
# 45 55
# 45 60
# 45 65
# 45 70
# 45 75
# 45 80
# 45 85
# 45 90
# 45 95
# 45 100
# 50 55
# 50 60
# 50 65
# 50 70
# 50 75
# 50 80
# 50 85
# 50 90
# 50 95
# 50 100
# 55 60
# 55 65
# 55 70
# 55 75
# 55 80
# 55 85
# 55 90
# 55 95
# 55 100
# 60 65
# 60 70
# 60 75
# 60 80
# 60 85
# 60 90
# 60 95
# 60 100
# 65 70
# 65 75
# 65 80
# 65 85
# 65 90
# 65 95
# 65 100
# 70 75
# 70 80
# 70 85
# 70 90
# 70 95
# 70 100
# 75 80
# 75 85
# 75 90
# 75 95
# 75 100
# 80 85
# 80 90
# 80 95
# 80 100
# 85 90
# 85 95
# 85 100
# 90 95
# 90 100
# 95 100
